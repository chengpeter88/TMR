# %%
# %% [markdown]
# # 06_機構資料爬取（5） - 爬取機構營業時間

# %% [markdown]
# ## 引入套件

# %%
import time
import pandas as pd
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
browser = webdriver.Chrome(service=ChromeService())
from bs4 import BeautifulSoup as Soup
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC


# %% [markdown]
# ## 首先，我們先執行到顯示"臺師大"頁面的地方，並利用Soup取得網頁元素框架

# %%
search= "臺灣師範大學"

# 開啟chromedriver
url = 'https://www.google.com.tw/maps?hl=zh-TW&tab=rl&authuser=0'  
browser.get(url)

# 輸入欲搜尋的店家名稱
WebDriverWait(browser, 30).until(EC.presence_of_element_located((By.CLASS_NAME, 'searchboxinput.xiQnY')))
search_input = browser.find_elements(By.CLASS_NAME,'searchboxinput.xiQnY')[0]
search_input.send_keys(search)

# 定位搜尋鍵並點擊
WebDriverWait(browser, 30).until(EC.presence_of_element_located((By.ID, 'searchbox-searchbutton')))

search_click = browser.find_elements(By.ID,'searchbox-searchbutton')[0]

search_click.click()

#選擇第一個點選

try:
    WebDriverWait(browser, 30).until(EC.presence_of_element_located((By.CLASS_NAME,'hfpxzc')))
    choose_first_item_click=browser.find_elements(By.CLASS_NAME,'hfpxzc')[0]
    choose_first_item_click.click()
except:
    print('不用點到第二層')
print("Finish Searching! " + search)

time.sleep(2.85)

soup = Soup(browser.page_source,"lxml")


# %% [markdown]
# ## 爬取學校營業時間

# %%
open_hour_frame=soup.find_all(class_="t39EBf GUrTXd")
#class="t39EBf GUrTXd" 是營業時間的class    
#%%
# ## 定義營業時間排序
weekday = ['星期日','星期一','星期二','星期三','星期四','星期五','星期六']

# %%
#
from util import business_hours
school_open_hours = business_hours(open_hour_frame, weekday)


# %% [markdown]
# ## 建立dataframe

# %%
school=pd.DataFrame({"學校名稱":search,"學校營業時間":school_open_hours})
school

browser.close()

# %% [markdown]
# <div aria-label="星期一、08:00 到 17:00; 星期二、08:00 到 17:00; 星期三、08:00 到 17:00; 星期四、08:00 到 17:00; 星期五、08:00 到 17:00; 星期六、休息; 星期日、休息. 隱藏本週營業時間" class="t39EBf GUrTXd"><div><table class="eK4R0e fontBodyMedium" style="font-family: Roboto, &quot;Noto Sans TC&quot;, Arial, sans-serif;"><tbody><tr class="y0skZc"><td class="ylH6lf fontTitleSmall" style="font-family: &quot;Google Sans&quot;, Roboto, &quot;Noto Sans TC&quot;, Arial, sans-serif;"><div>星期一</div></td><td class="mxowUb" role="text" aria-label="08:00 到 17:00"><ul class="fontTitleSmall" style="font-family: &quot;Google Sans&quot;, Roboto, &quot;Noto Sans TC&quot;, Arial, sans-serif;"><li class="G8aQO">08:00–17:00</li></ul></td><td class="HuudEc"><button class="mWUh3d" data-hide-tooltip-on-mouse-move="true" data-value="星期一、08:00–17:00" jsaction="pane.openhours.248.copy; ; focus:pane.focusTooltip; blur:pane.blurTooltip" data-tooltip="複製營業時間" aria-label="星期一、08:00 到 17:00、複製營業時間"><div class="OyjIsf "></div><div class="GYnni"></div></button></td></tr><tr class="y0skZc"><td class="ylH6lf "><div>星期二</div></td><td class="mxowUb" role="text" aria-label="08:00 到 17:00"><ul><li class="G8aQO">08:00–17:00</li></ul></td><td class="HuudEc"><button class="mWUh3d" data-hide-tooltip-on-mouse-move="true" data-value="星期二、08:00–17:00" jsaction="pane.openhours.248.copy; ; focus:pane.focusTooltip; blur:pane.blurTooltip" data-tooltip="複製營業時間" aria-label="星期二、08:00 到 17:00、複製營業時間"><div class="OyjIsf "></div><div class="GYnni"></div></button></td></tr><tr class="y0skZc"><td class="ylH6lf "><div>星期三</div></td><td class="mxowUb" role="text" aria-label="08:00 到 17:00"><ul><li class="G8aQO">08:00–17:00</li></ul></td><td class="HuudEc"><button class="mWUh3d" data-hide-tooltip-on-mouse-move="true" data-value="星期三、08:00–17:00" jsaction="pane.openhours.248.copy; ; focus:pane.focusTooltip; blur:pane.blurTooltip" data-tooltip="複製營業時間" aria-label="星期三、08:00 到 17:00、複製營業時間"><div class="OyjIsf "></div><div class="GYnni"></div></button></td></tr><tr class="y0skZc"><td class="ylH6lf "><div>星期四</div></td><td class="mxowUb" role="text" aria-label="08:00 到 17:00"><ul><li class="G8aQO">08:00–17:00</li></ul></td><td class="HuudEc"><button class="mWUh3d" data-hide-tooltip-on-mouse-move="true" data-value="星期四、08:00–17:00" jsaction="pane.openhours.248.copy; ; focus:pane.focusTooltip; blur:pane.blurTooltip" data-tooltip="複製營業時間" aria-label="星期四、08:00 到 17:00、複製營業時間"><div class="OyjIsf "></div><div class="GYnni"></div></button></td></tr><tr class="y0skZc"><td class="ylH6lf "><div>星期五</div></td><td class="mxowUb" role="text" aria-label="08:00 到 17:00"><ul><li class="G8aQO">08:00–17:00</li></ul></td><td class="HuudEc"><button class="mWUh3d" data-hide-tooltip-on-mouse-move="true" data-value="星期五、08:00–17:00" jsaction="pane.openhours.248.copy; ; focus:pane.focusTooltip; blur:pane.blurTooltip" data-tooltip="複製營業時間" aria-label="星期五、08:00 到 17:00、複製營業時間"><div class="OyjIsf "></div><div class="GYnni"></div></button></td></tr><tr class="y0skZc"><td class="ylH6lf "><div>星期六</div></td><td class="mxowUb" role="text" aria-label="休息"><ul><li class="G8aQO">休息</li></ul></td><td class="HuudEc"><button class="mWUh3d" data-hide-tooltip-on-mouse-move="true" data-value="星期六、休息" jsaction="pane.openhours.248.copy; ; focus:pane.focusTooltip; blur:pane.blurTooltip" data-tooltip="複製營業時間" aria-label="星期六、休息、複製營業時間"><div class="OyjIsf "></div><div class="GYnni"></div></button></td></tr><tr class="y0skZc"><td class="ylH6lf "><div>星期日</div></td><td class="mxowUb" role="text" aria-label="休息"><ul><li class="G8aQO">休息</li></ul></td><td class="HuudEc"><button class="mWUh3d" data-hide-tooltip-on-mouse-move="true" data-value="星期日、休息" jsaction="pane.openhours.248.copy; ; focus:pane.focusTooltip; blur:pane.blurTooltip" data-tooltip="複製營業時間" aria-label="星期日、休息、複製營業時間"><div class="OyjIsf "></div><div class="GYnni"></div></button></td></tr></tbody></table><div class="onOnO"><div class=""><button class="M77dve " aria-label="提出營業時間的修改建議" jslog="119438;track:click;mutable:true;metadata:WyIwYWhVS0V3ajN6c1RlcWV1RUF4VTNhZlVISFI2MEFOZ1E4QmNJQ1NnQiJd" jsaction="pane.wfvdle147"><div class="BgrMEd cYlvTc VOgY4 "><div class="OyjIsf zemfqc"></div><span class="wNNZR fontTitleSmall" style="font-family: &quot;Google Sans&quot;, Roboto, &quot;Noto Sans TC&quot;, Arial, sans-serif;">提供營業時間修改建議</span></div></button></div></div></div></div>

# %%
<div aria-label="星期一、08:00 到 17:00; 星期二、08:00 到 17:00; 星期三、08:00 到 17:00; 星期四、08:00 到 17:00; 星期五、08:00 到 17:00; 星期六、休息; 星期日、休息. 隱藏本週營業時間" class="t39EBf GUrTXd"><div><table class="eK4R0e fontBodyMedium" style="font-family: Roboto, &quot;Noto Sans TC&quot;, Arial, sans-serif;"><tbody><tr class="y0skZc"><td class="ylH6lf fontTitleSmall" style="font-family: &quot;Google Sans&quot;, Roboto, &quot;Noto Sans TC&quot;, Arial, sans-serif;"><div>星期一</div></td><td class="mxowUb" role="text" aria-label="08:00 到 17:00"><ul class="fontTitleSmall" style="font-family: &quot;Google Sans&quot;, Roboto, &quot;Noto Sans TC&quot;, Arial, sans-serif;"><li class="G8aQO">08:00–17:00</li></ul></td><td class="HuudEc"><button class="mWUh3d" data-hide-tooltip-on-mouse-move="true" data-value="星期一、08:00–17:00" jsaction="pane.openhours.248.copy; ; focus:pane.focusTooltip; blur:pane.blurTooltip" data-tooltip="複製營業時間" aria-label="星期一、08:00 到 17:00、複製營業時間"><div class="OyjIsf "></div><div class="GYnni"></div></button></td></tr><tr class="y0skZc"><td class="ylH6lf "><div>星期二</div></td><td class="mxowUb" role="text" aria-label="08:00 到 17:00"><ul><li class="G8aQO">08:00–17:00</li></ul></td><td class="HuudEc"><button class="mWUh3d" data-hide-tooltip-on-mouse-move="true" data-value="星期二、08:00–17:00" jsaction="pane.openhours.248.copy; ; focus:pane.focusTooltip; blur:pane.blurTooltip" data-tooltip="複製營業時間" aria-label="星期二、08:00 到 17:00、複製營業時間"><div class="OyjIsf "></div><div class="GYnni"></div></button></td></tr><tr class="y0skZc"><td class="ylH6lf "><div>星期三</div></td><td class="mxowUb" role="text" aria-label="08:00 到 17:00"><ul><li class="G8aQO">08:00–17:00</li></ul></td><td class="HuudEc"><button class="mWUh3d" data-hide-tooltip-on-mouse-move="true" data-value="星期三、08:00–17:00" jsaction="pane.openhours.248.copy; ; focus:pane.focusTooltip; blur:pane.blurTooltip" data-tooltip="複製營業時間" aria-label="星期三、08:00 到 17:00、複製營業時間"><div class="OyjIsf "></div><div class="GYnni"></div></button></td></tr><tr class="y0skZc"><td class="ylH6lf "><div>星期四</div></td><td class="mxowUb" role="text" aria-label="08:00 到 17:00"><ul><li class="G8aQO">08:00–17:00</li></ul></td><td class="HuudEc"><button class="mWUh3d" data-hide-tooltip-on-mouse-move="true" data-value="星期四、08:00–17:00" jsaction="pane.openhours.248.copy; ; focus:pane.focusTooltip; blur:pane.blurTooltip" data-tooltip="複製營業時間" aria-label="星期四、08:00 到 17:00、複製營業時間"><div class="OyjIsf "></div><div class="GYnni"></div></button></td></tr><tr class="y0skZc"><td class="ylH6lf "><div>星期五</div></td><td class="mxowUb" role="text" aria-label="08:00 到 17:00"><ul><li class="G8aQO">08:00–17:00</li></ul></td><td class="HuudEc"><button class="mWUh3d" data-hide-tooltip-on-mouse-move="true" data-value="星期五、08:00–17:00" jsaction="pane.openhours.248.copy; ; focus:pane.focusTooltip; blur:pane.blurTooltip" data-tooltip="複製營業時間" aria-label="星期五、08:00 到 17:00、複製營業時間"><div class="OyjIsf "></div><div class="GYnni"></div></button></td></tr><tr class="y0skZc"><td class="ylH6lf "><div>星期六</div></td><td class="mxowUb" role="text" aria-label="休息"><ul><li class="G8aQO">休息</li></ul></td><td class="HuudEc"><button class="mWUh3d" data-hide-tooltip-on-mouse-move="true" data-value="星期六、休息" jsaction="pane.openhours.248.copy; ; focus:pane.focusTooltip; blur:pane.blurTooltip" data-tooltip="複製營業時間" aria-label="星期六、休息、複製營業時間"><div class="OyjIsf "></div><div class="GYnni"></div></button></td></tr><tr class="y0skZc"><td class="ylH6lf "><div>星期日</div></td><td class="mxowUb" role="text" aria-label="休息"><ul><li class="G8aQO">休息</li></ul></td><td class="HuudEc"><button class="mWUh3d" data-hide-tooltip-on-mouse-move="true" data-value="星期日、休息" jsaction="pane.openhours.248.copy; ; focus:pane.focusTooltip; blur:pane.blurTooltip" data-tooltip="複製營業時間" aria-label="星期日、休息、複製營業時間"><div class="OyjIsf "></div><div class="GYnni"></div></button></td></tr></tbody></table><div class="onOnO"><div class=""><button class="M77dve " aria-label="提出營業時間的修改建議" jslog="119438;track:click;mutable:true;metadata:WyIwYWhVS0V3ajN6c1RlcWV1RUF4VTNhZlVISFI2MEFOZ1E4QmNJQ1NnQiJd" jsaction="pane.wfvdle147"><div class="BgrMEd cYlvTc VOgY4 "><div class="OyjIsf zemfqc"></div><span class="wNNZR fontTitleSmall" style="font-family: &quot;Google Sans&quot;, Roboto, &quot;Noto Sans TC&quot;, Arial, sans-serif;">提供營業時間修改建議</span></div></button></div></div></div></div>
